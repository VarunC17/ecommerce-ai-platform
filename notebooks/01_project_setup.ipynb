# %% [markdown]
# # E-Commerce AI Analytics Platform
#
# ## Project Setup
#
# This notebook initializes the environment for the E-Commerce AI Platform project.
#
# The project focuses on:
#
# - E-commerce sales analytics
# - Customer segmentation
# - Customer Lifetime Value (CLV)
# - Sales forecasting
# - Demand prediction
# - Product recommendation
# - Business intelligence and insights
#
# Dataset: Olist Brazilian E-Commerce Public Dataset

# %%
import os
import sys
import warnings

warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

print("libraries imported successfully")
# Out:
# libraries imported successfully

# %%
print("Python Version: ")
print(sys.version)
# Out:
# Python Version:
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]

# %%
print("Current Working Directory:")
print(os.getcwd())
# Out:
# Current Working Directory:
# C:\Users\asus\Documents\ECOMMERCE-AI-PLATFORM\notebooks

# %%
PROJECT_ROOT = os.path.dirname(os.getcwd())

print("Project Root:")
print(PROJECT_ROOT)
# Out:
# Project Root:
# C:\Users\asus\Documents\ECOMMERCE-AI-PLATFORM

# %%
DATA_DIR = os.path.join(PROJECT_ROOT, "data")
RAW_DATA_DIR = os.path.join(DATA_DIR,"raw")
PROCESSED_DATA_DIR = os.path.join(DATA_DIR, "processed")

NOTEBOOKS_DIR = os.path.join(PROJECT_ROOT, "notebooks")
OUTPUTS_DIR = os.path.join(PROJECT_ROOT, "outputs")
MODELS_DIR = os.path.join(PROJECT_ROOT, "models")
SRC_DIR = os.path.join(PROJECT_ROOT, "src")

# %%
print("Project Paths")
print("-" * 40)

print(f"Project Root       : {PROJECT_ROOT}")
print(f"Data Directory     : {DATA_DIR}")
print(f"Raw Data Directory : {RAW_DATA_DIR}")
print(f"Processed Data     : {PROCESSED_DATA_DIR}")
print(f"Notebooks          : {NOTEBOOKS_DIR}")
print(f"Outputs            : {OUTPUTS_DIR}")
print(f"Models             : {MODELS_DIR}")
print(f"Source Code        : {SRC_DIR}")
# Out:
# Project Paths
# ----------------------------------------
# Project Root       : C:\Users\asus\Documents\ECOMMERCE-AI-PLATFORM
# Data Directory     : C:\Users\asus\Documents\ECOMMERCE-AI-PLATFORM\data
# Raw Data Directory : C:\Users\asus\Documents\ECOMMERCE-AI-PLATFORM\data\raw
# Processed Data     : C:\Users\asus\Documents\ECOMMERCE-AI-PLATFORM\data\processed
# Notebooks          : C:\Users\asus\Documents\ECOMMERCE-AI-PLATFORM\notebooks
# Outputs            : C:\Users\asus\Documents\ECOMMERCE-AI-PLATFORM\outputs
# Models             : C:\Users\asus\Documents\ECOMMERCE-AI-PLATFORM\models
# Source Code        : C:\Users\asus\Documents\ECOMMERCE-AI-PLATFORM\src

# %%
folders = [
    DATA_DIR,
    RAW_DATA_DIR,
    PROCESSED_DATA_DIR,
    OUTPUTS_DIR,
    MODELS_DIR,
    SRC_DIR
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)

print("Required project folders are ready!")
# Out:
# Required project folders are ready!

# %%
if os.path.exists(RAW_DATA_DIR):
    print("Raw data folder found!")
    print(RAW_DATA_DIR)
else:
    print("Raw data folder not found!")
# Out:
# Raw data folder found!
# C:\Users\asus\Documents\ECOMMERCE-AI-PLATFORM\data\raw

# %%
print("RAW_DATA_DIR:", RAW_DATA_DIR)
print("Absolute path:", os.path.abspath(RAW_DATA_DIR))

print("\nFiles found:")

files = os.listdir(RAW_DATA_DIR)

if len(files) == 0:
    print("The folder is empty.")
else:
    for file in files:
        print(file)
# Out:
# RAW_DATA_DIR: C:\Users\asus\Documents\ECOMMERCE-AI-PLATFORM\data\raw
# Absolute path: C:\Users\asus\Documents\ECOMMERCE-AI-PLATFORM\data\raw
#
# Files found:
# olist_customers_dataset.csv
# olist_geolocation_dataset.csv
# olist_orders_dataset.csv
# olist_order_items_dataset.csv
# olist_order_payments_dataset.csv
# olist_order_reviews_dataset.csv
# olist_products_dataset.csv
# olist_sellers_dataset.csv
# product_category_name_translation.csv

# %%
files = os.listdir(RAW_DATA_DIR)

print(f"Total files found in raw data folder: {len(files)}")
# Out:
# Total files found in raw data folder: 9

# %%
expected_files = [
    "olist_customers_dataset.csv",
    "olist_geolocation_dataset.csv",
    "olist_order_items_dataset.csv",
    "olist_order_payments_dataset.csv",
    "olist_order_reviews_dataset.csv",
    "olist_orders_dataset.csv",
    "olist_products_dataset.csv",
    "olist_sellers_dataset.csv",
    "product_category_name_translation.csv"
]

print("Dataset File Verification")
print("-" * 40)

for file in expected_files:

    file_path = os.path.join(RAW_DATA_DIR, file)

    if os.path.exists(file_path):
        print(f"FOUND    : {file}")
    else:
        print(f"MISSING  : {file}")
# Out:
# Dataset File Verification
# ----------------------------------------
# FOUND    : olist_customers_dataset.csv
# FOUND    : olist_geolocation_dataset.csv
# FOUND    : olist_order_items_dataset.csv
# FOUND    : olist_order_payments_dataset.csv
# FOUND    : olist_order_reviews_dataset.csv
# FOUND    : olist_orders_dataset.csv
# FOUND    : olist_products_dataset.csv
# FOUND    : olist_sellers_dataset.csv
# FOUND    : product_category_name_translation.csv

# %%
print("Raw Dataset File Information")
print("-" * 50)

for file in os.listdir(RAW_DATA_DIR):

    file_path = os.path.join(RAW_DATA_DIR, file)

    file_size = os.path.getsize(file_path) / (1024 * 1024)

    print(f"{file:<45} {file_size:.2f} MB")
# Out:
# Raw Dataset File Information
# --------------------------------------------------
# olist_customers_dataset.csv                   8.62 MB
# olist_geolocation_dataset.csv                 58.44 MB
# olist_orders_dataset.csv                      16.84 MB
# olist_order_items_dataset.csv                 14.72 MB
# olist_order_payments_dataset.csv              5.51 MB
# olist_order_reviews_dataset.csv               13.78 MB
# olist_products_dataset.csv                    2.27 MB
# olist_sellers_dataset.csv                     0.17 MB
# product_category_name_translation.csv         0.00 MB

# %%
print("=" * 60)
print("ECOMMERCE-AI-PLATFORM PROJECT SETUP COMPLETE")
print("=" * 60)

print(f"Project Root: {PROJECT_ROOT}")
print(f"Raw Data Available: {os.path.exists(RAW_DATA_DIR)}")
print(f"Number of Raw Files: {len(os.listdir(RAW_DATA_DIR))}")
print("Environment Status: READY")
# Out:
# ...
# ECOMMERCE-AI-PLATFORM PROJECT SETUP COMPLETE
# ...
# Project Root: C:\Users\asus\Documents\ECOMMERCE-AI-PLATFORM
# Raw Data Available: True
# Number of Raw Files: 9
# Environment Status: READY
